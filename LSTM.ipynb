# %% [markdown]
# # KERAS LSTM HURRICANE PREDICTION DATA PREPARATION #

# %%
import pandas as pd
import numpy as np
from pandas import read_csv
from datetime import datetime

# %% [markdown]
# After importing the needed modules, the CSV file can be parsed using pandas. The `date_parser` option is used in order to later ensure that training takes place on consecutive, observations spaced six hours apart.

# %%
def parse_date(raw):
    return datetime.strptime(raw, "%Y%m%d%H")
data = read_csv('data/cleaned.csv', parse_dates = ['datetime'], date_parser=parse_date)

# %% [markdown]
# The following code iterates row by row over the csv file and collects consecutive observations separated by exactly six hours from a particular weather event. This is possible because the csv is sorted in chronological order grouped according to the weather event (*the 'id' field*). It also normalizes the location features to a value 0-1. This has been observed to improve the performance of the network.

# %%
gc = 1 #group size counter
gs = 5 #group size target
nrows = len(data)
ri = 1 #row index
test_and_train = []


prev_row = data.iloc[0]

def get_normalized_row(index):
    return [(data.iloc[index]['latitude']),(data.iloc[index]['longitude']),(data.iloc[index]['maximumwind'])]

cg = [get_normalized_row(ri)] #current group
while ri < nrows:
    if gc < gs:
        if data.iloc[ri]['id'] == prev_row['id'] and (data.iloc[ri]['datetime'] - prev_row['datetime']).seconds == 21600:
            cg.append(get_normalized_row(ri))
            gc += 1
        else:
            cg = [get_normalized_row(ri)]
            gc = 1
        prev_row = data.iloc[ri]
        ri += 1
    else:
        test_and_train.append(cg)
        cg = [get_normalized_row(ri)]
        gc = 1
        prev_row = data.iloc[ri]
        ri += 1

# %% [markdown]
# We can see in the next cell that we successfully created 13673 data groups.

# %%
num_groups = len(test_and_train)
test_and_train = np.array(test_and_train)
num_groups
# Out:
# 13673

# %%
#Use validation_split in keras fit function for automatic splitting
#train = np.array(test_and_train[:-ttsplit])
#test = np.array(test_and_train[-ttsplit:])

# %% [markdown]
# Now that we have our data set (contained in the test_and_train variable), we can import the keras modules to build the network.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, LSTM
from keras.optimizers import RMSprop
from keras.callbacks import LearningRateScheduler
# Out:
# Using TensorFlow backend.

# %% [markdown]
# The following function is a callback called each epoch of the fit function. This allows us to start with a higher learning rate that gets decays over time to ruduce overall training time without sacrificing accuracy.

# %%
def lr_decay(epoch):
    if epoch < 2: return 0.01
    if epoch < 6: return 0.001
    return 0.0001

# %%
def lr_min(epoch):
    return 0.0001

# %% [markdown]
# Originally attempted to use adam optimizer and tried a variety of different configurations of network.

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(4,3), return_sequences=False)) #Input layer, LSTM with 48 neurons
model.add(Dense(16))
model.add(Dense(3))

#optimizer = RMSprop(0.0001)
model.compile(loss="mae", optimizer='rmsprop', metrics=['acc'])
#model.compile(loss="mse", optimizer='adam', metrics=['acc']) #adam optimizer performed worse than RMSprop

# %% [markdown]
# Need to reshape the dataset before fitting.

# %%
X, y = test_and_train[:,:4].reshape(num_groups,4,3), test_and_train[:,-1].reshape(num_groups,3)

# %%
#model.fit(X, y, epochs=20, batch_size=50, validation_split=0.01, verbose=2, callbacks=[LearningRateScheduler(lr_decay)])
model.fit(X, y, epochs=200, batch_size=10, validation_split=0.01, verbose=2, callbacks=[LearningRateScheduler(lr_min)])
# Out:
# Train on 13536 samples, validate on 137 samples
# Epoch 1/200
#  - 16s - loss: 1.4240 - acc: 0.9792 - val_loss: 1.2411 - val_acc: 0.9781
# Epoch 2/200
#  - 16s - loss: 1.4228 - acc: 0.9789 - val_loss: 1.2282 - val_acc: 0.9781
# Epoch 3/200
#  - 16s - loss: 1.4214 - acc: 0.9793 - val_loss: 1.2355 - val_acc: 0.9781
# Epoch 4/200
#  - 17s - loss: 1.4193 - acc: 0.9793 - val_loss: 1.2579 - val_acc: 0.9781
# Epoch 5/200
#  - 16s - loss: 1.4172 - acc: 0.9793 - val_loss: 1.2408 - val_acc: 0.9781
# Epoch 6/200
#  - 17s - loss: 1.4166 - acc: 0.9792 - val_loss: 1.2311 - val_acc: 0.9781
# Epoch 7/200
#  - 16s - loss: 1.4157 - acc: 0.9787 - val_loss: 1.2424 - val_acc: 0.9781
# Epoch 8/200
#  - 16s - loss: 1.4134 - acc: 0.9792 - val_loss: 1.2384 - val_acc: 0.9781
# Epoch 9/200
#  - 16s - loss: 1.4130 - acc: 0.9793 - val_loss: 1.2384 - val_acc: 0.9781
# Epoch 10/200
#  - 16s - loss: 1.4117 - acc: 0.9798 - val_loss: 1.2427 - val_acc: 0.9781
# Epoch 11/200
#  - 16s - loss: 1.4109 - acc: 0.9794 - val_loss: 1.2342 - val_acc: 0.9781
# Epoch 12/200
#  - 16s - loss: 1.4108 - acc: 0.9792 - val_loss: 1.2193 - val_acc: 0.9781
# Epoch 13/200
#  - 16s - loss: 1.4088 - acc: 0.9796 - val_loss: 1.2410 - val_acc: 0.9781
# Epoch 14/200
#  - 16s - loss: 1.4081 - acc: 0.9798 - val_loss: 1.2216 - val_acc: 0.9781
# Epoch 15/200
#  - 17s - loss: 1.4088 - acc: 0.9791 - val_loss: 1.2180 - val_acc: 0.9781
# Epoch 16/200
#  - 17s - loss: 1.4071 - acc: 0.9801 - val_loss: 1.2288 - val_acc: 0.9781
# Epoch 17/200
#  - 16s - loss: 1.4043 - acc: 0.9795 - val_loss: 1.2389 - val_acc: 0.9781
# Epoch 18/200
#  - 16s - loss: 1.4052 - acc: 0.9795 - val_loss: 1.2475 - val_acc: 0.9854
# Epoch 19/200
#  - 16s - loss: 1.4034 - acc: 0.9794 - val_loss: 1.2239 - val_acc: 0.9781
# Epoch 20/200
#  - 16s - loss: 1.4016 - acc: 0.9795 - val_loss: 1.2158 - val_acc: 0.9781
# Epoch 21/200
#  - 16s - loss: 1.4030 - acc: 0.9793 - val_loss: 1.2358 - val_acc: 0.9708
# Epoch 22/200
#  - 17s - loss: 1.4017 - acc: 0.9794 - val_loss: 1.2391 - val_acc: 0.9781
# Epoch 23/200
#  - 16s - loss: 1.4002 - acc: 0.9795 - val_loss: 1.2250 - val_acc: 0.9781
# Epoch 24/200
#  - 16s - loss: 1.3986 - acc: 0.9796 - val_loss: 1.2134 - val_acc: 0.9781
# Epoch 25/200
#  - 16s - loss: 1.3989 - acc: 0.9795 - val_loss: 1.2327 - val_acc: 0.9854
# Epoch 26/200
#  - 16s - loss: 1.3969 - acc: 0.9795 - val_loss: 1.2226 - val_acc: 0.9781
# Epoch 27/200
#  - 16s - loss: 1.3982 - acc: 0.9801 - val_loss: 1.2276 - val_acc: 0.9781
# Epoch 28/200
#  - 16s - loss: 1.3966 - acc: 0.9791 - val_loss: 1.2195 - val_acc: 0.9781
# Epoch 29/200
#  - 17s - loss: 1.3958 - acc: 0.9792 - val_loss: 1.2184 - val_acc: 0.9781
# Epoch 30/200
#  - 16s - loss: 1.3950 - acc: 0.9795 - val_loss: 1.2463 - val_acc: 0.9708
# Epoch 31/200
#  - 16s - loss: 1.3952 - acc: 0.9797 - val_loss: 1.2200 - val_acc: 0.9781
# Epoch 32/200
#  - 16s - loss: 1.3933 - acc: 0.9798 - val_loss: 1.2251 - val_acc: 0.9854
# Epoch 33/200
#  - 17s - loss: 1.3915 - acc: 0.9797 - val_loss: 1.2133 - val_acc: 0.9781
# Epoch 34/200
#  - 16s - loss: 1.3927 - acc: 0.9792 - val_loss: 1.2354 - val_acc: 0.9781
# Epoch 35/200
#  - 17s - loss: 1.3898 - acc: 0.9792 - val_loss: 1.2292 - val_acc: 0.9781
# Epoch 36/200
#  - 16s - loss: 1.3892 - acc: 0.9795 - val_loss: 1.2215 - val_acc: 0.9781
# Epoch 37/200
#  - 17s - loss: 1.3884 - acc: 0.9798 - val_loss: 1.2170 - val_acc: 0.9781
# Epoch 38/200
#  - 17s - loss: 1.3866 - acc: 0.9793 - val_loss: 1.2032 - val_acc: 0.9781
# Epoch 39/200
#  - 16s - loss: 1.3858 - acc: 0.9798 - val_loss: 1.2287 - val_acc: 0.9854
# Epoch 40/200
#  - 16s - loss: 1.3853 - acc: 0.9798 - val_loss: 1.2153 - val_acc: 0.9781
# Epoch 41/200
#  - 16s - loss: 1.3854 - acc: 0.9798 - val_loss: 1.2506 - val_acc: 0.9781
# Epoch 42/200
#  - 16s - loss: 1.3858 - acc: 0.9794 - val_loss: 1.2287 - val_acc: 0.9781
# Epoch 43/200
#  - 16s - loss: 1.3852 - acc: 0.9793 - val_loss: 1.2176 - val_acc: 0.9781
# Epoch 44/200
#  - 17s - loss: 1.3855 - acc: 0.9792 - val_loss: 1.2402 - val_acc: 0.9781
# Epoch 45/200
#  - 17s - loss: 1.3839 - acc: 0.9795 - val_loss: 1.2191 - val_acc: 0.9781
# Epoch 46/200
#  - 16s - loss: 1.3833 - acc: 0.9795 - val_loss: 1.2367 - val_acc: 0.9781
# Epoch 47/200
#  - 16s - loss: 1.3834 - acc: 0.9798 - val_loss: 1.2281 - val_acc: 0.9708
# Epoch 48/200
#  - 17s - loss: 1.3815 - acc: 0.9795 - val_loss: 1.2314 - val_acc: 0.9781
# Epoch 49/200
#  - 17s - loss: 1.3815 - acc: 0.9796 - val_loss: 1.2171 - val_acc: 0.9708
# Epoch 50/200
#  - 16s - loss: 1.3811 - acc: 0.9792 - val_loss: 1.2305 - val_acc: 0.9781
# Epoch 51/200
#  - 17s - loss: 1.3787 - acc: 0.9791 - val_loss: 1.2164 - val_acc: 0.9781
# Epoch 52/200
#  - 17s - loss: 1.3788 - acc: 0.9798 - val_loss: 1.2144 - val_acc: 0.9781
# Epoch 53/200
#  - 17s - loss: 1.3764 - acc: 0.9798 - val_loss: 1.2309 - val_acc: 0.9781
# Epoch 54/200
#  - 16s - loss: 1.3775 - acc: 0.9801 - val_loss: 1.2028 - val_acc: 0.9781
# Epoch 55/200
#  - 16s - loss: 1.3765 - acc: 0.9797 - val_loss: 1.2100 - val_acc: 0.9854
# Epoch 56/200
#  - 17s - loss: 1.3744 - acc: 0.9795 - val_loss: 1.2209 - val_acc: 0.9854
# Epoch 57/200
#  - 16s - loss: 1.3750 - acc: 0.9797 - val_loss: 1.2148 - val_acc: 0.9781
# Epoch 58/200
#  - 17s - loss: 1.3728 - acc: 0.9793 - val_loss: 1.2278 - val_acc: 0.9781
# Epoch 59/200
#  - 16s - loss: 1.3742 - acc: 0.9789 - val_loss: 1.2158 - val_acc: 0.9781
# Epoch 60/200
#  - 16s - loss: 1.3748 - acc: 0.9792 - val_loss: 1.2171 - val_acc: 0.9781
# Epoch 61/200
#  - 17s - loss: 1.3723 - acc: 0.9790 - val_loss: 1.2088 - val_acc: 0.9781
# Epoch 62/200
#  - 16s - loss: 1.3715 - acc: 0.9795 - val_loss: 1.2313 - val_acc: 0.9781
# Epoch 63/200
#  - 16s - loss: 1.3726 - acc: 0.9792 - val_loss: 1.2166 - val_acc: 0.9781
# Epoch 64/200
#  - 16s - loss: 1.3695 - acc: 0.9792 - val_loss: 1.2121 - val_acc: 0.9781
# Epoch 65/200
#  - 16s - loss: 1.3710 - acc: 0.9797 - val_loss: 1.2189 - val_acc: 0.9781
# Epoch 66/200
#  - 17s - loss: 1.3698 - acc: 0.9792 - val_loss: 1.2130 - val_acc: 0.9781
# Epoch 67/200
#  - 16s - loss: 1.3682 - acc: 0.9788 - val_loss: 1.2308 - val_acc: 0.9708
# Epoch 68/200
#  - 16s - loss: 1.3672 - acc: 0.9795 - val_loss: 1.2140 - val_acc: 0.9781
# Epoch 69/200
#  - 16s - loss: 1.3680 - acc: 0.9797 - val_loss: 1.2197 - val_acc: 0.9781
# Epoch 70/200
#  - 16s - loss: 1.3666 - acc: 0.9794 - val_loss: 1.2168 - val_acc: 0.9708
# Epoch 71/200
#  - 17s - loss: 1.3665 - acc: 0.9798 - val_loss: 1.2273 - val_acc: 0.9781
# Epoch 72/200
#  - 16s - loss: 1.3652 - acc: 0.9797 - val_loss: 1.2189 - val_acc: 0.9781
# Epoch 73/200
#  - 17s - loss: 1.3649 - acc: 0.9793 - val_loss: 1.2186 - val_acc: 0.9854
# Epoch 74/200
#  - 16s - loss: 1.3647 - acc: 0.9792 - val_loss: 1.2146 - val_acc: 0.9708
# Epoch 75/200
#  - 17s - loss: 1.3647 - acc: 0.9798 - val_loss: 1.2118 - val_acc: 0.9708
# Epoch 76/200
#  - 16s - loss: 1.3636 - acc: 0.9792 - val_loss: 1.2241 - val_acc: 0.9781
# Epoch 77/200
#  - 16s - loss: 1.3628 - acc: 0.9796 - val_loss: 1.2226 - val_acc: 0.9781
# Epoch 78/200
#  - 17s - loss: 1.3631 - acc: 0.9795 - val_loss: 1.2381 - val_acc: 0.9781
# Epoch 79/200
#  - 17s - loss: 1.3628 - acc: 0.9792 - val_loss: 1.2236 - val_acc: 0.9708
# Epoch 80/200
#  - 17s - loss: 1.3627 - acc: 0.9797 - val_loss: 1.2266 - val_acc: 0.9781
# Epoch 81/200
#  - 16s - loss: 1.3599 - acc: 0.9798 - val_loss: 1.2290 - val_acc: 0.9781
# Epoch 82/200
#  - 16s - loss: 1.3613 - acc: 0.9795 - val_loss: 1.2134 - val_acc: 0.9781
# Epoch 83/200
#  - 16s - loss: 1.3593 - acc: 0.9799 - val_loss: 1.2214 - val_acc: 0.9708
# Epoch 84/200
#  - 17s - loss: 1.3597 - acc: 0.9797 - val_loss: 1.2248 - val_acc: 0.9708
# Epoch 85/200
#  - 16s - loss: 1.3593 - acc: 0.9792 - val_loss: 1.2056 - val_acc: 0.9708
# Epoch 86/200
#  - 16s - loss: 1.3593 - acc: 0.9796 - val_loss: 1.2162 - val_acc: 0.9708
# Epoch 87/200
#  - 17s - loss: 1.3589 - acc: 0.9794 - val_loss: 1.2236 - val_acc: 0.9781
# Epoch 88/200
#  - 17s - loss: 1.3573 - acc: 0.9795 - val_loss: 1.2313 - val_acc: 0.9708
# Epoch 89/200
#  - 16s - loss: 1.3566 - acc: 0.9795 - val_loss: 1.2064 - val_acc: 0.9781
# Epoch 90/200
#  - 16s - loss: 1.3549 - acc: 0.9798 - val_loss: 1.2031 - val_acc: 0.9708
# Epoch 91/200
#  - 17s - loss: 1.3566 - acc: 0.9795 - val_loss: 1.2347 - val_acc: 0.9708
# Epoch 92/200
#  - 16s - loss: 1.3561 - acc: 0.9789 - val_loss: 1.2106 - val_acc: 0.9781
# Epoch 93/200
#  - 16s - loss: 1.3555 - acc: 0.9795 - val_loss: 1.2365 - val_acc: 0.9708
# Epoch 94/200
#  - 16s - loss: 1.3549 - acc: 0.9797 - val_loss: 1.2250 - val_acc: 0.9708
# Epoch 95/200
#  - 17s - loss: 1.3544 - acc: 0.9791 - val_loss: 1.2355 - val_acc: 0.9854
# Epoch 96/200
#  - 16s - loss: 1.3536 - acc: 0.9798 - val_loss: 1.2076 - val_acc: 0.9781
# Epoch 97/200
#  - 16s - loss: 1.3518 - acc: 0.9798 - val_loss: 1.2165 - val_acc: 0.9708
# Epoch 98/200
#  - 17s - loss: 1.3525 - acc: 0.9790 - val_loss: 1.2330 - val_acc: 0.9781
# Epoch 99/200
#  - 17s - loss: 1.3522 - acc: 0.9798 - val_loss: 1.2191 - val_acc: 0.9708
# Epoch 100/200
#  - 16s - loss: 1.3522 - acc: 0.9795 - val_loss: 1.2125 - val_acc: 0.9854
# Epoch 101/200
#  - 16s - loss: 1.3521 - acc: 0.9794 - val_loss: 1.2067 - val_acc: 0.9708
# Epoch 102/200
#  - 17s - loss: 1.3516 - acc: 0.9797 - val_loss: 1.2240 - val_acc: 0.9781
# Epoch 103/200
#  - 16s - loss: 1.3513 - acc: 0.9795 - val_loss: 1.2207 - val_acc: 0.9708
# Epoch 104/200
#  - 16s - loss: 1.3507 - acc: 0.9798 - val_loss: 1.2164 - val_acc: 0.9708
# Epoch 105/200
#  - 16s - loss: 1.3495 - acc: 0.9795 - val_loss: 1.2521 - val_acc: 0.9708
# Epoch 106/200
#  - 16s - loss: 1.3505 - acc: 0.9792 - val_loss: 1.2313 - val_acc: 0.9708
# Epoch 107/200
#  - 17s - loss: 1.3498 - acc: 0.9797 - val_loss: 1.2047 - val_acc: 0.9708
# Epoch 108/200
#  - 16s - loss: 1.3484 - acc: 0.9792 - val_loss: 1.2146 - val_acc: 0.9708
# Epoch 109/200
#  - 17s - loss: 1.3469 - acc: 0.9795 - val_loss: 1.2032 - val_acc: 0.9708
# Epoch 110/200
#  - 16s - loss: 1.3481 - acc: 0.9801 - val_loss: 1.2094 - val_acc: 0.9708
# Epoch 111/200
#  - 16s - loss: 1.3469 - acc: 0.9794 - val_loss: 1.1985 - val_acc: 0.9781
# Epoch 112/200
#  - 17s - loss: 1.3473 - acc: 0.9795 - val_loss: 1.2051 - val_acc: 0.9781
# Epoch 113/200
#  - 17s - loss: 1.3464 - acc: 0.9796 - val_loss: 1.2105 - val_acc: 0.9708
# Epoch 114/200
#  - 16s - loss: 1.3477 - acc: 0.9796 - val_loss: 1.2131 - val_acc: 0.9708
# Epoch 115/200
#  - 16s - loss: 1.3460 - acc: 0.9790 - val_loss: 1.2060 - val_acc: 0.9708
# Epoch 116/200
#  - 16s - loss: 1.3448 - acc: 0.9793 - val_loss: 1.2107 - val_acc: 0.9781
# Epoch 117/200
#  - 17s - loss: 1.3441 - acc: 0.9794 - val_loss: 1.2059 - val_acc: 0.9708
# Epoch 118/200
#  - 16s - loss: 1.3439 - acc: 0.9796 - val_loss: 1.2065 - val_acc: 0.9708
# Epoch 119/200
#  - 16s - loss: 1.3446 - acc: 0.9792 - val_loss: 1.1912 - val_acc: 0.9708
# Epoch 120/200
#  - 16s - loss: 1.3438 - acc: 0.9798 - val_loss: 1.1968 - val_acc: 0.9708
# Epoch 121/200
#  - 16s - loss: 1.3430 - acc: 0.9798 - val_loss: 1.1998 - val_acc: 0.9708
# Epoch 122/200
#  - 16s - loss: 1.3434 - acc: 0.9792 - val_loss: 1.2530 - val_acc: 0.9781
# Epoch 123/200
#  - 16s - loss: 1.3423 - acc: 0.9798 - val_loss: 1.2023 - val_acc: 0.9781
# Epoch 124/200
#  - 17s - loss: 1.3410 - acc: 0.9793 - val_loss: 1.1982 - val_acc: 0.9708
# Epoch 125/200
#  - 16s - loss: 1.3422 - acc: 0.9798 - val_loss: 1.2116 - val_acc: 0.9708
# Epoch 126/200
#  - 16s - loss: 1.3405 - acc: 0.9798 - val_loss: 1.1905 - val_acc: 0.9781
# Epoch 127/200
#  - 16s - loss: 1.3405 - acc: 0.9801 - val_loss: 1.2125 - val_acc: 0.9854
# Epoch 128/200
#  - 16s - loss: 1.3396 - acc: 0.9794 - val_loss: 1.1958 - val_acc: 0.9781
# Epoch 129/200
#  - 16s - loss: 1.3395 - acc: 0.9796 - val_loss: 1.2149 - val_acc: 0.9708
# Epoch 130/200
#  - 16s - loss: 1.3391 - acc: 0.9801 - val_loss: 1.2519 - val_acc: 0.9708
# Epoch 131/200
#  - 17s - loss: 1.3394 - acc: 0.9791 - val_loss: 1.2073 - val_acc: 0.9708
# Epoch 132/200
#  - 16s - loss: 1.3382 - acc: 0.9798 - val_loss: 1.1963 - val_acc: 0.9781
# Epoch 133/200
#  - 17s - loss: 1.3377 - acc: 0.9789 - val_loss: 1.2193 - val_acc: 0.9781
# Epoch 134/200
#  - 16s - loss: 1.3378 - acc: 0.9791 - val_loss: 1.2017 - val_acc: 0.9708
# Epoch 135/200
#  - 16s - loss: 1.3373 - acc: 0.9789 - val_loss: 1.1952 - val_acc: 0.9708
# Epoch 136/200
#  - 16s - loss: 1.3382 - acc: 0.9800 - val_loss: 1.1845 - val_acc: 0.9708
# Epoch 137/200
#  - 16s - loss: 1.3358 - acc: 0.9793 - val_loss: 1.1945 - val_acc: 0.9708
# Epoch 138/200
#  - 17s - loss: 1.3361 - acc: 0.9796 - val_loss: 1.2060 - val_acc: 0.9781
# Epoch 139/200
#  - 16s - loss: 1.3357 - acc: 0.9795 - val_loss: 1.2128 - val_acc: 0.9708
# Epoch 140/200
#  - 16s - loss: 1.3358 - acc: 0.9796 - val_loss: 1.2113 - val_acc: 0.9781
# Epoch 141/200
#  - 16s - loss: 1.3352 - acc: 0.9795 - val_loss: 1.1984 - val_acc: 0.9708
# Epoch 142/200
#  - 16s - loss: 1.3348 - acc: 0.9789 - val_loss: 1.2017 - val_acc: 0.9708
# Epoch 143/200
#  - 16s - loss: 1.3339 - acc: 0.9795 - val_loss: 1.1848 - val_acc: 0.9708
# Epoch 144/200
#  - 16s - loss: 1.3336 - acc: 0.9793 - val_loss: 1.1913 - val_acc: 0.9708
# Epoch 145/200
#  - 16s - loss: 1.3332 - acc: 0.9794 - val_loss: 1.1934 - val_acc: 0.9708
# Epoch 146/200
#  - 17s - loss: 1.3333 - acc: 0.9799 - val_loss: 1.1847 - val_acc: 0.9708
# Epoch 147/200
#  - 16s - loss: 1.3329 - acc: 0.9796 - val_loss: 1.1815 - val_acc: 0.9708
# Epoch 148/200
#  - 17s - loss: 1.3327 - acc: 0.9798 - val_loss: 1.1908 - val_acc: 0.9708
# Epoch 149/200
#  - 16s - loss: 1.3305 - acc: 0.9792 - val_loss: 1.2189 - val_acc: 0.9708
# Epoch 150/200
#  - 16s - loss: 1.3314 - acc: 0.9802 - val_loss: 1.2036 - val_acc: 0.9708
# Epoch 151/200
#  - 16s - loss: 1.3309 - acc: 0.9792 - val_loss: 1.1873 - val_acc: 0.9708
# Epoch 152/200
#  - 16s - loss: 1.3317 - acc: 0.9792 - val_loss: 1.1873 - val_acc: 0.9708
# Epoch 153/200
#  - 17s - loss: 1.3285 - acc: 0.9793 - val_loss: 1.1936 - val_acc: 0.9708
# Epoch 154/200
#  - 16s - loss: 1.3305 - acc: 0.9796 - val_loss: 1.2011 - val_acc: 0.9708
# Epoch 155/200
#  - 16s - loss: 1.3289 - acc: 0.9802 - val_loss: 1.1915 - val_acc: 0.9781
# Epoch 156/200
#  - 17s - loss: 1.3290 - acc: 0.9798 - val_loss: 1.1976 - val_acc: 0.9708
# Epoch 157/200
#  - 17s - loss: 1.3278 - acc: 0.9796 - val_loss: 1.1896 - val_acc: 0.9708
# Epoch 158/200
#  - 16s - loss: 1.3284 - acc: 0.9794 - val_loss: 1.1945 - val_acc: 0.9708
# Epoch 159/200
#  - 16s - loss: 1.3266 - acc: 0.9794 - val_loss: 1.2066 - val_acc: 0.9708
# Epoch 160/200
#  - 17s - loss: 1.3268 - acc: 0.9795 - val_loss: 1.1887 - val_acc: 0.9708
# Epoch 161/200
#  - 16s - loss: 1.3281 - acc: 0.9796 - val_loss: 1.1954 - val_acc: 0.9708
# Epoch 162/200
#  - 16s - loss: 1.3265 - acc: 0.9798 - val_loss: 1.2112 - val_acc: 0.9708
# Epoch 163/200
#  - 17s - loss: 1.3268 - acc: 0.9795 - val_loss: 1.2019 - val_acc: 0.9708
# Epoch 164/200
#  - 17s - loss: 1.3261 - acc: 0.9797 - val_loss: 1.2064 - val_acc: 0.9708
# Epoch 165/200
#  - 17s - loss: 1.3264 - acc: 0.9799 - val_loss: 1.1927 - val_acc: 0.9708
# Epoch 166/200
#  - 16s - loss: 1.3261 - acc: 0.9798 - val_loss: 1.2098 - val_acc: 0.9708
# Epoch 167/200
#  - 16s - loss: 1.3257 - acc: 0.9796 - val_loss: 1.1900 - val_acc: 0.9708
# Epoch 168/200
#  - 17s - loss: 1.3258 - acc: 0.9799 - val_loss: 1.2217 - val_acc: 0.9708
# Epoch 169/200
#  - 16s - loss: 1.3235 - acc: 0.9798 - val_loss: 1.1939 - val_acc: 0.9708
# Epoch 170/200
#  - 16s - loss: 1.3245 - acc: 0.9795 - val_loss: 1.1965 - val_acc: 0.9708
# Epoch 171/200
#  - 16s - loss: 1.3237 - acc: 0.9798 - val_loss: 1.1845 - val_acc: 0.9708
# Epoch 172/200
#  - 16s - loss: 1.3245 - acc: 0.9798 - val_loss: 1.1918 - val_acc: 0.9708
# Epoch 173/200
#  - 17s - loss: 1.3234 - acc: 0.9797 - val_loss: 1.1951 - val_acc: 0.9708
# Epoch 174/200
#  - 16s - loss: 1.3231 - acc: 0.9796 - val_loss: 1.1734 - val_acc: 0.9708
# Epoch 175/200
#  - 17s - loss: 1.3234 - acc: 0.9795 - val_loss: 1.1814 - val_acc: 0.9708
# Epoch 176/200
#  - 17s - loss: 1.3233 - acc: 0.9799 - val_loss: 1.2037 - val_acc: 0.9708
# Epoch 177/200
#  - 16s - loss: 1.3209 - acc: 0.9798 - val_loss: 1.1870 - val_acc: 0.9781
# Epoch 178/200
#  - 16s - loss: 1.3213 - acc: 0.9798 - val_loss: 1.2290 - val_acc: 0.9708
# Epoch 179/200
#  - 17s - loss: 1.3209 - acc: 0.9793 - val_loss: 1.1896 - val_acc: 0.9708
# Epoch 180/200
#  - 17s - loss: 1.3223 - acc: 0.9794 - val_loss: 1.1757 - val_acc: 0.9708
# Epoch 181/200
#  - 16s - loss: 1.3193 - acc: 0.9797 - val_loss: 1.1668 - val_acc: 0.9708
# Epoch 182/200
#  - 17s - loss: 1.3197 - acc: 0.9795 - val_loss: 1.1987 - val_acc: 0.9781
# Epoch 183/200
#  - 16s - loss: 1.3218 - acc: 0.9799 - val_loss: 1.1910 - val_acc: 0.9781
# Epoch 184/200
#  - 16s - loss: 1.3193 - acc: 0.9795 - val_loss: 1.1578 - val_acc: 0.9708
# Epoch 185/200
#  - 16s - loss: 1.3189 - acc: 0.9795 - val_loss: 1.1974 - val_acc: 0.9708
# Epoch 186/200
#  - 16s - loss: 1.3195 - acc: 0.9793 - val_loss: 1.2041 - val_acc: 0.9708
# Epoch 187/200
#  - 16s - loss: 1.3194 - acc: 0.9798 - val_loss: 1.1783 - val_acc: 0.9708
# Epoch 188/200
#  - 17s - loss: 1.3180 - acc: 0.9800 - val_loss: 1.1837 - val_acc: 0.9781
# Epoch 189/200
#  - 17s - loss: 1.3191 - acc: 0.9798 - val_loss: 1.1714 - val_acc: 0.9708
# Epoch 190/200
#  - 16s - loss: 1.3194 - acc: 0.9796 - val_loss: 1.1869 - val_acc: 0.9708
# Epoch 191/200
#  - 16s - loss: 1.3178 - acc: 0.9795 - val_loss: 1.1814 - val_acc: 0.9708
# Epoch 192/200
#  - 16s - loss: 1.3180 - acc: 0.9795 - val_loss: 1.1856 - val_acc: 0.9708
# Epoch 193/200
#  - 16s - loss: 1.3182 - acc: 0.9801 - val_loss: 1.1680 - val_acc: 0.9708
# Epoch 194/200
#  - 16s - loss: 1.3177 - acc: 0.9789 - val_loss: 1.1886 - val_acc: 0.9708
# Epoch 195/200
#  - 16s - loss: 1.3171 - acc: 0.9798 - val_loss: 1.1930 - val_acc: 0.9708
# Epoch 196/200
#  - 16s - loss: 1.3188 - acc: 0.9797 - val_loss: 1.1566 - val_acc: 0.9708
# Epoch 197/200
#  - 16s - loss: 1.3170 - acc: 0.9792 - val_loss: 1.1691 - val_acc: 0.9708
# Epoch 198/200
#  - 16s - loss: 1.3158 - acc: 0.9794 - val_loss: 1.1757 - val_acc: 0.9708
# Epoch 199/200
#  - 16s - loss: 1.3170 - acc: 0.9798 - val_loss: 1.1763 - val_acc: 0.9781
# Epoch 200/200
#  - 16s - loss: 1.3162 - acc: 0.9793 - val_loss: 1.1635 - val_acc: 0.9708

# %%
lat_s = 0
lon_s = 0
ws_s = 0
lat_f = 0
lon_f = 0
ws_f = 0
lat_err = 0
lon_err = 0
ws_err = 0

for iter in range(num_groups):
    gt = model.predict(X[iter].reshape(1,4,3))
    pred = y[iter]
    if abs(gt[0][0] - pred[0]) <= 0.1:
        lat_s += 1
    else:
        lat_f += 1
    if abs(gt[0][1] - pred[1]) <= 0.2:
        lon_s += 1
    else:
        lon_f += 1
    if abs(gt[0][2] - pred[2]) <= 1:
        ws_s += 1
    else:
        ws_f += 1
    lat_err += abs(gt[0][0] - pred[0])
    lon_err += abs(gt[0][1] - pred[1])
    ws_err += abs(gt[0][2] - pred[2])

# %%
lat_acc = (lat_s/(num_groups))*100
lat_err /= num_groups
lon_acc = (lon_s/(num_groups))*100
lon_err /= num_groups
ws_acc = (ws_s/(num_groups))*100
ws_err /= num_groups

print("Lattitude prediction threshold success rate = ", lat_acc)
print("Lattitude average error = ", lat_err)
print("Longitude prediction threshold success rate = ", lon_acc)
print("Longitude average error = ", lon_err)
print("Wind Speed prediction threshold success rate = ", ws_acc)
print("Wind Speed average error = ", ws_err)
# Out:
# Lattitude prediction threshold success rate =  30.395670299129673
# Lattitude average error =  0.266207645751
# Longitude prediction threshold success rate =  39.34030571198713
# Longitude average error =  0.687404977967
# Wind Speed prediction threshold success rate =  41.41739194032034
# Wind Speed average error =  2.96868602724
